# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer
import seaborn as sns

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.base import TransformerMixin

# %%
# from sklearn.ensemble import forest,RandomForestClassifier,ExtraTreesClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
# from sklearn.svm import SVC
# from sklearn.grid_search import GridSearchCV,RandomizedSearchCV
# from sklearn.cross_validation import StratifiedKSplit
# from sklearn.

# %%
df_train = pd.read_csv('Dataset/train.csv')
df_gs = pd.read_csv('Dataset/gender_submission.csv')
df_test = pd.read_csv('Dataset/test.csv')

# %%
y = df_train['Survived']
df_train_copy = df_train.copy()
df_train_copy.drop(['PassengerId','Survived','Name'],axis=1,inplace=True)
df_train.drop(['PassengerId','Survived','Name','Ticket','Age'],axis=1,inplace=True)
df_test.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)

# %%
df_train.head()
# Out:
#    Pclass     Sex  SibSp  Parch     Fare Cabin Embarked
# 0       3    male      1      0   7.2500   NaN        S
# 1       1  female      1      0  71.2833   C85        C
# 2       3  female      0      0   7.9250   NaN        S
# 3       1  female      1      0  53.1000  C123        S
# 4       3    male      0      0   8.0500   NaN        S

# %%
df_train.describe()
# Out:
#            Pclass       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean     2.308642    0.523008    0.381594   32.204208
# std      0.836071    1.102743    0.806057   49.693429
# min      1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    0.000000    7.910400
# 50%      3.000000    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000    0.000000   31.000000
# max      3.000000    8.000000    6.000000  512.329200

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# Pclass      891 non-null int64
# Sex         891 non-null object
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 48.8+ KB

# %%
for col in df_train.columns:
    print("{} has {} unique values".format(col,df_train[col].nunique()))
# Out:
# Pclass has 3 unique values
# Sex has 2 unique values
# SibSp has 7 unique values
# Parch has 7 unique values
# Fare has 248 unique values
# Cabin has 147 unique values
# Embarked has 3 unique values

# %%
class CategoryTransformer(TransformerMixin):
    def fit(self,X,y=None):
        return self
    def transform(self,X):
        for col in X.columns:
            if X[col].dtype.name == 'object':
                X[col] = X[col].astype('category')
                X[col] = X[col].cat.codes
        return X

# %%
df_train = CategoryTransformer().transform(df_train)

# %%
df_train.head()
# Out:
#    Pclass  Sex  SibSp  Parch     Fare  Cabin  Embarked
# 0       3    1      1      0   7.2500     -1         2
# 1       1    0      1      0  71.2833     81         0
# 2       3    0      0      0   7.9250     -1         2
# 3       1    0      1      0  53.1000     55         2
# 4       3    1      0      0   8.0500     -1         2

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
# Pclass      891 non-null int64
# Sex         891 non-null int8
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Fare        891 non-null float64
# Cabin       891 non-null int16
# Embarked    891 non-null int8
# dtypes: float64(1), int16(1), int64(3), int8(2)
# memory usage: 31.4 KB

# %%
df_train.isna().sum()
# Out:
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
class NullTransformer(TransformerMixin):
    def transform(self,X):
        imputer = Imputer(axis=1)
        X = pd.DataFrame(imputer.fit_transform(X),columns=X.columns)
        return X

# %%
df_train = NullTransformer().transform(df_train)

# %%
df_train.isna().sum()
# Out:
# Pclass      0
# Sex         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
kfold = StratifiedKFold(n_splits=10,random_state=42)
fig, ax = plt.subplots(5,2,figsize=(10,20))
for i,(train_idx,valid_idx) in enumerate(kfold.split(df_train,y)):
    X_train,y_train = df_train.iloc[train_idx],y[train_idx]
    X_valid,y_valid = df_train.iloc[valid_idx],y[valid_idx]
    lr = LogisticRegression(penalty='l1',random_state=42)
    lr.fit(X_train,y_train)
    y_pred = lr.predict(X_valid)
#     print(accuracy_score(y_pred=y_pred,y_true=y_valid))
    row = i//2
    col = i%2
    ax[row,col].plot(df_train.columns,lr.coef_.reshape(len(df_train.columns),1))
    ax[row,col]
    ax[row,col].set_title(accuracy_score(y_pred=y_pred,y_true=y_valid))
plt.show()

# %%
kfold = StratifiedKFold(n_splits=10,random_state=42)
df_train_copy.drop(['Ticket'],axis=1,inplace=True)
df_train = CategoryTransformer().transform(df_train_copy)
df_train = NullTransformer().transform(df_train)
fig, ax = plt.subplots(5,2,figsize=(20,40))
for i,(train_idx,valid_idx) in enumerate(kfold.split(df_train,y)):
    X_train,y_train = df_train.iloc[train_idx],y[train_idx]
    X_valid,y_valid = df_train.iloc[valid_idx],y[valid_idx]
    rf = RandomForestClassifier(20,min_samples_split=10,random_state=23,max_leaf_nodes=30,oob_score=True)
    rf.fit(X_train,y_train)
    y_pred = rf.predict(X_valid)
    print(accuracy_score(y_pred=y_pred,y_true=y_valid))
    row = i//2
    col = i%2
    ax[row,col].bar(range(0,len(rf.feature_importances_)),rf.feature_importances_)
    ax[row,col].set_xticklabels(df_train.columns)
    ax[row,col].set_xlim(0, len(rf.feature_importances_))
    ax[row,col].set_title(accuracy_score(y_pred=y_pred,y_true=y_valid))
plt.show()
# Out:
# 0.7888888888888889
# 0.7888888888888889
# 0.7752808988764045
# 0.8426966292134831
# 0.9101123595505618
# 0.8314606741573034
# 0.8202247191011236
# 0.797752808988764
# 0.8314606741573034
# 0.8522727272727273

# %%
df_test = CategoryTransformer().transform(df_test)
df_test = NullTransformer().transform(df_test)
y_pred = rf.predict(df_test)

# %%
df_gs['Survived'] = y_pred

# %%
df_gs.to_csv('output.csv',index=False)

# %%
##This solution gives 76.55% accuracy
